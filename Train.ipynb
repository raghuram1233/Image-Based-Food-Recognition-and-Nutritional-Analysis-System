# %% [markdown]
# ## Importing Modules

# %%
import os
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential                   #type: ignore
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout#type: ignore
from tensorflow.keras.losses import sparse_categorical_crossentropy#type: ignore
from tensorflow.keras.optimizers import Adam#type: ignore
from tensorflow.keras.preprocessing.image import ImageDataGenerator#type: ignore

# %% [markdown]
# ## Loading the Dataset

# %%
main_dir = "Data"
os.listdir(main_dir)
# Out:
# ['test', 'train']

# %%
test_dir = main_dir + '/test'
os.listdir(test_dir)
# Out:
# ['Apple', 'Banana', 'Mango', 'Orange', 'Pineapple']

# %%
train_dir = main_dir + '/train'
os.listdir(train_dir)
# Out:
# ['Apple', 'Banana', 'Mango', 'Orange', 'Pineapple']

# %% [markdown]
# ## Train Set

# %%
# Creating a data generator
train = ImageDataGenerator(
  rescale=1./255, 
    horizontal_flip = True,
    vertical_flip = True,
    validation_split = 0.2
)
train_datagen = train.flow_from_directory(
        train_dir,
        batch_size=32,
        target_size=(128,128),
        class_mode='sparse',
        subset = 'training')

val_datagen = train.flow_from_directory(
        train_dir,
        batch_size=32,
        target_size=(128,128),
        class_mode='sparse',
        subset = 'validation')

# Printing the training set
train_labels = (train_datagen.class_indices)
print(train_labels)
# Out:
# Found 1800 images belonging to 5 classes.
# Found 445 images belonging to 5 classes.
# {'Apple': 0, 'Banana': 1, 'Mango': 2, 'Orange': 3, 'Pineapple': 4}

# %% [markdown]
# ## Test Set

# %%
# Create a data generator
test_datagen = ImageDataGenerator(
  rescale=1./255,
    horizontal_flip = True,
    vertical_flip = True
)
test_datagen = test_datagen.flow_from_directory(
        test_dir,
        batch_size=32,
        target_size=(128,128),
        class_mode='sparse')

# Printing the test set
test_labels = (test_datagen.class_indices)
print(test_labels)
# Out:
# Found 755 images belonging to 5 classes.
# {'Apple': 0, 'Banana': 1, 'Mango': 2, 'Orange': 3, 'Pineapple': 4}

# %% [markdown]
# ## Image Configuration

# %%
for image_batch, label_batch in train_datagen:
    break
image_batch.shape, label_batch.shape

# This would be same for test set
# Out:
# ((32, 128, 128, 3), (32,))

# %% [markdown]
# ## Building the Model

# %%
model=Sequential()

#Convolution blocks
model.add(Conv2D(32, kernel_size = (3,3), 
                 padding='same',
                 input_shape=(128,128,3),
                 activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

model.add(Conv2D(64, kernel_size = (3,3), 
                 padding='same',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

model.add(Conv2D(32, kernel_size = (3,3), 
                 padding='same',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=2))

#Classification layers
model.add(Flatten())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32,activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(5,activation='softmax'))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 64)                524352
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 564,453
# Trainable params: 564,453
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compiling the Model

# %%
model.compile(optimizer = 'Adam', 
              loss = 'sparse_categorical_crossentropy', 
              metrics = ['accuracy'])

# %% [markdown]
# ## Training the Model

# %%
trained_model = model.fit(train_datagen, epochs=50, 
                          batch_size = 32, 
                          validation_data = val_datagen, verbose = 1)
# Out:
# Epoch 1/50
# 57/57 [==============================] - 10s 50ms/step - loss: 1.4478 - accuracy: 0.3400 - val_loss: 0.9614 - val_accuracy: 0.5865
# Epoch 2/50
# 57/57 [==============================] - 2s 31ms/step - loss: 0.8379 - accuracy: 0.6544 - val_loss: 0.4923 - val_accuracy: 0.7775
# Epoch 3/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.6605 - accuracy: 0.7489 - val_loss: 0.3596 - val_accuracy: 0.9393
# Epoch 4/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.6382 - accuracy: 0.7572 - val_loss: 0.3013 - val_accuracy: 0.9303
# Epoch 5/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.5881 - accuracy: 0.7761 - val_loss: 1.0119 - val_accuracy: 0.7596
# Epoch 6/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.5183 - accuracy: 0.8144 - val_loss: 0.2963 - val_accuracy: 0.9461
# Epoch 7/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.5148 - accuracy: 0.8083 - val_loss: 0.2477 - val_accuracy: 0.9258
# Epoch 8/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.4706 - accuracy: 0.8272 - val_loss: 0.3655 - val_accuracy: 0.8360
# Epoch 9/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.4619 - accuracy: 0.8344 - val_loss: 0.2195 - val_accuracy: 0.9416
# Epoch 10/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.4480 - accuracy: 0.8350 - val_loss: 0.2555 - val_accuracy: 0.9483
# Epoch 11/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.4508 - accuracy: 0.8411 - val_loss: 0.3812 - val_accuracy: 0.8427
# Epoch 12/50
# 57/57 [==============================] - 2s 31ms/step - loss: 0.3950 - accuracy: 0.8672 - val_loss: 0.2396 - val_accuracy: 0.9461
# Epoch 13/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.3907 - accuracy: 0.8622 - val_loss: 0.4123 - val_accuracy: 0.7978
# Epoch 14/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.3994 - accuracy: 0.8594 - val_loss: 0.2803 - val_accuracy: 0.9348
# Epoch 15/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.3696 - accuracy: 0.8606 - val_loss: 0.2217 - val_accuracy: 0.9461
# Epoch 16/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.3269 - accuracy: 0.8800 - val_loss: 0.2323 - val_accuracy: 0.9551
# Epoch 17/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.3738 - accuracy: 0.8667 - val_loss: 0.2337 - val_accuracy: 0.9371
# Epoch 18/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.3175 - accuracy: 0.8789 - val_loss: 0.3174 - val_accuracy: 0.9213
# Epoch 19/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.3391 - accuracy: 0.8811 - val_loss: 0.2905 - val_accuracy: 0.9303
# Epoch 20/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.3144 - accuracy: 0.8883 - val_loss: 0.2045 - val_accuracy: 0.9528
# Epoch 21/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.2775 - accuracy: 0.9000 - val_loss: 0.2619 - val_accuracy: 0.9528
# Epoch 22/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.2862 - accuracy: 0.8972 - val_loss: 0.2457 - val_accuracy: 0.9326
# Epoch 23/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.3060 - accuracy: 0.8889 - val_loss: 0.2656 - val_accuracy: 0.9483
# Epoch 24/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.2945 - accuracy: 0.8961 - val_loss: 0.2797 - val_accuracy: 0.8899
# Epoch 25/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.2582 - accuracy: 0.9089 - val_loss: 0.3498 - val_accuracy: 0.8517
# Epoch 26/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.2381 - accuracy: 0.9128 - val_loss: 0.2835 - val_accuracy: 0.9438
# Epoch 27/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.2393 - accuracy: 0.9144 - val_loss: 0.2771 - val_accuracy: 0.9506
# Epoch 28/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.2083 - accuracy: 0.9267 - val_loss: 0.2124 - val_accuracy: 0.9483
# Epoch 29/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.1949 - accuracy: 0.9300 - val_loss: 0.1933 - val_accuracy: 0.9551
# Epoch 30/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.2235 - accuracy: 0.9228 - val_loss: 0.2502 - val_accuracy: 0.9146
# Epoch 31/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.2170 - accuracy: 0.9206 - val_loss: 0.2211 - val_accuracy: 0.9551
# Epoch 32/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.1950 - accuracy: 0.9239 - val_loss: 0.1982 - val_accuracy: 0.9573
# Epoch 33/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1788 - accuracy: 0.9372 - val_loss: 0.2092 - val_accuracy: 0.9573
# Epoch 34/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.2332 - accuracy: 0.9144 - val_loss: 0.2081 - val_accuracy: 0.9461
# Epoch 35/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.2036 - accuracy: 0.9250 - val_loss: 0.2609 - val_accuracy: 0.9551
# Epoch 36/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.2067 - accuracy: 0.9294 - val_loss: 0.2000 - val_accuracy: 0.9528
# Epoch 37/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1597 - accuracy: 0.9367 - val_loss: 0.2428 - val_accuracy: 0.9393
# Epoch 38/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1432 - accuracy: 0.9411 - val_loss: 0.2058 - val_accuracy: 0.9573
# Epoch 39/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.1465 - accuracy: 0.9456 - val_loss: 0.2077 - val_accuracy: 0.9483
# Epoch 40/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1642 - accuracy: 0.9417 - val_loss: 0.2201 - val_accuracy: 0.9551
# Epoch 41/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.1635 - accuracy: 0.9489 - val_loss: 0.2073 - val_accuracy: 0.9640
# Epoch 42/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1416 - accuracy: 0.9550 - val_loss: 0.2242 - val_accuracy: 0.9596
# Epoch 43/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1452 - accuracy: 0.9444 - val_loss: 0.3300 - val_accuracy: 0.9303
# Epoch 44/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1734 - accuracy: 0.9422 - val_loss: 0.2038 - val_accuracy: 0.9618
# Epoch 45/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1756 - accuracy: 0.9400 - val_loss: 0.2012 - val_accuracy: 0.9528
# Epoch 46/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1428 - accuracy: 0.9489 - val_loss: 0.1612 - val_accuracy: 0.9685
# Epoch 47/50
# 57/57 [==============================] - 2s 30ms/step - loss: 0.1378 - accuracy: 0.9494 - val_loss: 0.1833 - val_accuracy: 0.9618
# Epoch 48/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1119 - accuracy: 0.9594 - val_loss: 0.1905 - val_accuracy: 0.9663
# Epoch 49/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1180 - accuracy: 0.9544 - val_loss: 0.2063 - val_accuracy: 0.9663
# Epoch 50/50
# 57/57 [==============================] - 2s 29ms/step - loss: 0.1247 - accuracy: 0.9561 - val_loss: 0.2022 - val_accuracy: 0.9663

# %% [markdown]
# ## Saving the Model

# %%
model_dir = 'Fruits_model.h5'
model.save(model_dir)

# %%
from tensorflow import keras
model = keras.models.load_model(model_dir)

# %% [markdown]
# ## Testing the model

# %%
# Test 1

from tensorflow.keras.preprocessing import image#type: ignore
import numpy as np
test_img = test_dir + '/Apple/sample1.jpg'
img = image.load_img(test_img, target_size = (128,128))
img_array = image.img_to_array(img)
img_array = np.array(img_array)/255.0

# Getting the labels
labels = dict((value,key) for key, value in train_labels.items())
predictions = model.predict(img_array[np.newaxis])#type: ignore

# Displaying the output
acc = np.max(predictions[0]) * 100
print(f'Accuracy: {acc}%')
result = labels[np.argmax(predictions[0], axis = -1)]
print(f'Output: {result}')

plt.axis('off')
plt.imshow(img)
# Out:
# 1/1 [==============================] - 0s 156ms/step
# Accuracy: 99.89915490150452%
# Output: Apple

# %% [markdown]
# ## Evaluating the result

# %%
acc = trained_model.history['accuracy']
val_acc = trained_model.history['val_accuracy']
loss = trained_model.history['loss']
val_loss = trained_model.history['val_loss']

epochs_range = range(50)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
